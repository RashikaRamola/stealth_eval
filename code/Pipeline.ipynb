# %%
import numpy as np
import pandas as pd
import gzip
import csv
import io
import argparse

import subprocess
import multiprocessing
import time

import sys
sys.path.append("/home/rashika/CAFA4/InformationAccretion/")
sys.path.append("/home/rashika/CAFA4/CAFA-evaluator/src/cafaeval/")
from parser import *
from ia import *
from make_benchmarks import *

# %%
ls /home/rashika/CAFA4/CAFA-evaluator/src/cafaeval/
# Out:
# data/          graph.py     __main__.py  __pycache__/
# evaluation.py  __init__.py  parser.py

# %%
# Preprocess
#preprocess_cmd = "python3 run_preprocess_parallel.py"
#result = subprocess.run(preprocess_cmd, shell=True)

# %%
# To do:
# Modify preprocess_cmd to take all the input/output/log paths as inputs
# Incorporate in the code of main() block

# %% [markdown]
# # To do
#
# Do the system commands more elegantly, parallelise the evaluation, incorporate the bootstrapping

# %%
"""
    Read a the processed annotation file, map the primary ID to a mapping file, and keep the rows that can be mapped.

    Parameters:
    - processed_file_path: Path to the file containing processed GOA annotations
    - mapping_file: Path to the mapping file 
    - out_path: Path to the output file.
    """
def goa_to_CAFA4ID(processed_file_path, mapping_file, out_path):
    ann = pd.read_csv(processed_file_path, sep = '\t', header = 0)
    mapping = pd.read_csv(mapping_file, sep = '\t', header = 0)

    # Inner join the processed annotations and the mapping based on DB Object ID
    mapped =  pd.merge(ann, mapping, on='DB Object ID', how='inner')
    
    
    # Keep the required columns
    mapped = mapped[["CAFA4_ID", "GO ID", "Aspect"]]
    
    # Write the mapped file to the out_path
    mapped.to_csv(out_path, sep = "\t", index=False, header=None)

# %%
def get_preprocess_cmd(gaf_path, out_path):
    cmd = [
    "python3",                 # Command to execute Python 3
    "preprocess_gaf.py",       # Script to run
    gaf_path,  # Path to input file
    "--highTP",
    "--out_path", out_path,        # Output path parameter
    #"--evidence_codes", "EXP", "IDA",   # Evidence codes parameter
    #"--extract_col_list", "DB Object ID", "Qualifier"  # Extract column list parameter
]
    return cmd

def run_process(command, log_file):
    with open(log_file, "w") as f:
        print(command)
        result = subprocess.run(" ".join(command), shell=True, stdout=f, stderr=subprocess.STDOUT)


if __name__ == "__main__":
    # Define commands and log file names
    work_dir = "/data/rashika/CAFA4/"
    
    t0_gaf_file = work_dir + "uniprot/raw_goa/t0/goa_uniprot_all.gaf.195.gz" # The latest Uniprot file before t1 ( 2019-12-17)
    t0_processed = work_dir + "extracted_goa/t0_preprocessed.csv"
    log_t0 =  work_dir + "log/log_preprocess_t0.txt"
    
    #t1_gaf_file = work_dir + "uniprot/raw_goa/t1/goa_uniprot_all.gaf.gz" # The file from UniProt (2024-02-09)
    t1_gaf_file = work_dir + "uniprot/uniprot_2024_2024-04-16/goa_uniprot_all.gaf.gz" # The file from UniProt 2024-04-16
    t1_processed = work_dir + "extracted_goa/t1_preprocessed.csv"
    log_t1 = work_dir + "log/log_preprocess_t1.txt"
    
    
    cmd_preprocess_t0 = get_preprocess_cmd(t0_gaf_file, t0_processed)
    cmd_preprocess_t1 = get_preprocess_cmd(t1_gaf_file, t1_processed)
    
    # Create processes for each command
    process1 = multiprocessing.Process(target=run_process, args=(cmd_preprocess_t0, log_t0))
    process2 = multiprocessing.Process(target=run_process, args=(cmd_preprocess_t1, log_t1))
    
    # Start the processes
    #process1.start()
    #process2.start()

    # Wait for both processes to finish
    #process1.join()
    #process2.join()

    #print("Both processes have finished.")
    
    # Map the IDs of the processed 
    
    work_dir = "/data/rashika/CAFA4/"
    mapping_file = "/data/rashika/CAFA4/CAFA4-export/AC2CAFA4ID.map"
    t0_mapped_path = work_dir + "mapped/t0.csv"
    t1_mapped_path = work_dir + "/mapped/t1.csv"
    
    # Map to CAFA4 IDs 
    #goa_to_CAFA4ID(t0_processed , mapping_file, t0_mapped_path)
    #goa_to_CAFA4ID(t1_processed , mapping_file, t1_mapped_path)
    
    # Create the benchmarks
    roots = {'BPO': 'GO:0008150', 'CCO': 'GO:0005575', 'MFO': 'GO:0003674'}

    #eval_path = work_dir + "eval/"

    t0_ont_file = '/data/rashika/CAFA4/uniprot/go_2019_12_09/go-basic.obo' # data-version: releases/2020-01-01
    t0_ont_graph = clean_ontology_edges(obonet.read_obo(t0_ont_file))     
    
    t1_ont_file = "/data/rashika/CAFA4/uniprot/go_2024_03_28/go-basic.obo"
    t1_ont_graph = clean_ontology_edges(obonet.read_obo(t1_ont_file)) # data-version: releases/2024-01-17
    
    t_minus_ont_file =  "/data/rashika/CAFA4/uniprot/go_2019_10_07/go-basic.obo"
    t_minus_1_ont_graph = clean_ontology_edges(obonet.read_obo(t_minus_ont_file))

    # Create BM lists
    eval_path = '/data/rashika/CAFA4/eval_final/'
    BM_GO_path = eval_path + "BM_GO/"
    common_path = '/data/rashika/CAFA4/common/'
    #create_bm_lists(t0_mapped_path, t1_mapped_path, t0_ont_graph, t1_ont_graph, t_minus_1_ont_graph, roots, BM_GO_path, common_path)


    # Calculate IA
    IA_file =  eval_path + "IA.txt"
    #print(IA_file)
    #cmd = 'python3 /home/rashika/CAFA4/InformationAccretion/ia.py --annot ' + t0_processed + ' --graph '+ t_minus_ont_file + ' --outfile ' + IA_file + ' --prop' 
    #os.system(cmd)
    
    pred_dir = "/data/yisupeng/sharing/cafa4/all_models/"
    
    result_path = eval_path + "eval_results/"
    #run_eval(BM_GO_path, pred_dir, t_minus_ont_file, IA_file, result_path, log_path = '/home/rashika/CAFA4/eval/log/', thresh_step = 0.001)
    #cmd = 'python3 /home/rashika/CAFA4/CAFA-evaluator/src/cafaeval/__main__.py /data/rashika/CAFA4/uniprot/go_2019_10_07/go-basic.obo /data/yisupeng/sharing/cafa4/all_models/ /data/rashika/CAFA4/eval_final/BM_GO/bpo_all_type3.txt -out_dir /data/rashika/CAFA4/eval_final/eval_results/bpo_all_type3/ -ia /data/rashika/CAFA4/eval_final/IA.txt -prop max -th_step 0.01 -no_orphans > /home/rashika/CAFA4/eval/log/bpo_all_type3/run.log &'
    os.system(cmd)
    # Paths
    plots_path =  eval_path + 'plots_ALL/'
    if not os.path.exists(plots_path):
        os.mkdir(plots_path)
    plots_path_f_w = plots_path+'f_w/'
    plots_path_f = plots_path+'f/'
    plots_path_f_micro = plots_path+'f_micro/'
    plots_path_f_micro_w = plots_path+'f_micro_w/'
    plots_path_s_w = plots_path+'s_w/'
    register = '/data/rashika/CAFA4/file_map.tsv'


#     metric, cols = ('f_w', ['rc_w', 'pr_w'])
#     create_plots(result_path, metric, cols, out_path= plots_path_f_w, n_curves = 10, names_file = register)

#     metric, cols = ('f', ['rc', 'pr'])
#     create_plots(result_path, metric, cols, out_path = plots_path_f, n_curves = 10, names_file =register)

#     metric, cols =  ('f_micro_w', ['rc_micro_w', 'pr_micro_w'])
#     create_plots(result_path, metric, cols, out_path = plots_path_f_micro_w, n_curves = 10, names_file =register)

#     metric, cols =  ('f_micro', ['rc_micro', 'pr_micro'])
#     create_plots(result_path, metric, cols, out_path = plots_path_f_micro, n_curves = 10, names_file =register)

#     metric, cols = ('s_w', ['ru_w', 'mi_w'])
#     create_plots(result_path, metric, cols, out_path = plots_path_s_w, n_curves = 10, names_file =register)
# Out:
# 2024-06-27 23:37:39,113 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M046, cellular_component, proteins 1076, annotations 97890, replaced alt. ids 2042
# 2024-06-27 23:37:54,785 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M022, cellular_component, proteins 2308, annotations 153266, replaced alt. ids 0
# 2024-06-27 23:37:57,313 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M022, evaluated
# 2024-06-27 23:37:59,212 [INFO ] Ontology: biological_process, total 29456, roots 1, leaves 13559, alternative_ids 1474
# 2024-06-27 23:38:00,083 [INFO ] Ontology: molecular_function, total 11092, roots 1, leaves 9061, alternative_ids 897
# 2024-06-27 23:38:00,203 [INFO ] Ontology: cellular_component, total 4182, roots 1, leaves 2775, alternative_ids 181
# 2024-06-27 23:38:00,510 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M022, evaluated
# 2024-06-27 23:38:16,747 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M118, evaluated
# 2024-06-27 23:38:32,233 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M046, cellular_component, proteins 1045, annotations 109268, replaced alt. ids 2188
# 2024-06-27 23:38:34,066 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M046, evaluated
# 2024-06-27 23:38:36,218 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M046, cellular_component, proteins 1076, annotations 97890, replaced alt. ids 2042
# 2024-06-27 23:38:36,356 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M046, evaluated
# 2024-06-27 23:38:42,506 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M022, cellular_component, proteins 2308, annotations 153266, replaced alt. ids 0
# 2024-06-27 23:38:45,509 [INFO ] Ground truth: biological_process, proteins 24010, annotations 582803, replaced alt. ids 0
# 2024-06-27 23:38:59,274 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M018, cellular_component, proteins 1142, annotations 77132, replaced alt. ids 0
# 2024-06-27 23:39:01,034 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M018, cellular_component, proteins 1166, annotations 77020, replaced alt. ids 0
# 2024-06-27 23:39:35,746 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M046, evaluated
# 2024-06-27 23:39:44,047 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M046, evaluated
# 2024-06-27 23:40:01,054 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M018, cellular_component, proteins 1166, annotations 77020, replaced alt. ids 0
# 2024-06-27 23:40:04,862 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M018, evaluated
# 2024-06-27 23:40:10,106 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M018, evaluated
# 2024-06-27 23:40:10,754 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M018, cellular_component, proteins 1142, annotations 77132, replaced alt. ids 0
# 2024-06-27 23:40:14,921 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M118, biological_process, proteins 23987, annotations 12580905, replaced alt. ids 0
# 2024-06-27 23:40:25,770 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M012, cellular_component, proteins 1166, annotations 27804, replaced alt. ids 0
# 2024-06-27 23:40:29,466 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M012, cellular_component, proteins 1142, annotations 22447, replaced alt. ids 0
# 2024-06-27 23:40:37,993 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M022, evaluated
# 2024-06-27 23:40:51,081 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M118, evaluated
# 2024-06-27 23:40:55,760 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M022, evaluated
# 2024-06-27 23:41:02,215 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M018, evaluated
# 2024-06-27 23:41:06,682 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M046, cellular_component, proteins 2121, annotations 207158, replaced alt. ids 4230
# 2024-06-27 23:41:15,630 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M022, molecular_function, proteins 2016, annotations 220154, replaced alt. ids 0
# 2024-06-27 23:41:17,681 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M018, evaluated
# 2024-06-27 23:41:19,315 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M012, evaluated
# 2024-06-27 23:41:22,236 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M118, biological_process, proteins 23987, annotations 12580905, replaced alt. ids 0
# 2024-06-27 23:41:24,058 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M012, cellular_component, proteins 1142, annotations 22447, replaced alt. ids 0
# 2024-06-27 23:41:30,185 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M046, cellular_component, proteins 2121, annotations 207158, replaced alt. ids 4230
# 2024-06-27 23:41:36,483 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M012, evaluated
# 2024-06-27 23:41:38,160 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M012, cellular_component, proteins 1166, annotations 27804, replaced alt. ids 0
# 2024-06-27 23:42:38,104 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M012, evaluated
# 2024-06-27 23:42:44,393 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M012, evaluated
# 2024-06-27 23:42:48,103 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M118, evaluated
# 2024-06-27 23:42:53,816 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M056, cellular_component, proteins 1142, annotations 455072, replaced alt. ids 0
# 2024-06-27 23:43:01,160 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M056, cellular_component, proteins 1166, annotations 442485, replaced alt. ids 0
# 2024-06-27 23:43:19,343 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M022, molecular_function, proteins 2016, annotations 220154, replaced alt. ids 0
# 2024-06-27 23:43:37,076 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M118, evaluated
# 2024-06-27 23:44:00,585 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M046, evaluated
# 2024-06-27 23:44:03,237 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M056, cellular_component, proteins 1142, annotations 455072, replaced alt. ids 0
# 2024-06-27 23:44:03,367 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M118, evaluated
# 2024-06-27 23:44:05,509 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M056, evaluated
# 2024-06-27 23:44:06,265 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M056, evaluated
# 2024-06-27 23:44:08,437 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M056, cellular_component, proteins 1166, annotations 442485, replaced alt. ids 0
# 2024-06-27 23:44:22,610 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M022, biological_process, proteins 1318, annotations 748085, replaced alt. ids 0
# 2024-06-27 23:44:22,661 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M118, evaluated
# 2024-06-27 23:44:25,862 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M018, cellular_component, proteins 2308, annotations 154152, replaced alt. ids 0
# 2024-06-27 23:44:25,996 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M046, evaluated
# 2024-06-27 23:44:50,607 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M018, cellular_component, proteins 2308, annotations 154152, replaced alt. ids 0
# 2024-06-27 23:44:52,585 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M022, molecular_function, proteins 2682, annotations 291202, replaced alt. ids 0
# 2024-06-27 23:44:56,172 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M118, evaluated
# 2024-06-27 23:44:57,671 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M022, biological_process, proteins 1318, annotations 748085, replaced alt. ids 0
# 2024-06-27 23:45:06,956 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M056, evaluated
# 2024-06-27 23:45:14,707 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M056, evaluated
# 2024-06-27 23:45:24,154 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M118, evaluated
# 2024-06-27 23:45:32,973 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M065, cellular_component, proteins 1142, annotations 796673, replaced alt. ids 0
# 2024-06-27 23:45:32,986 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M065, cellular_component, proteins 1166, annotations 810947, replaced alt. ids 0
# 2024-06-27 23:45:51,045 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M022, biological_process, proteins 1455, annotations 807123, replaced alt. ids 0
# 2024-06-27 23:45:51,447 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M022, molecular_function, proteins 2682, annotations 291202, replaced alt. ids 0
# 2024-06-27 23:46:33,044 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M118, evaluated
# 2024-06-27 23:46:35,823 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M065, cellular_component, proteins 1142, annotations 796673, replaced alt. ids 0
# 2024-06-27 23:46:40,863 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M065, evaluated
# 2024-06-27 23:46:43,888 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M077, cellular_component, proteins 758, annotations 8495, replaced alt. ids 0
# 2024-06-27 23:46:46,724 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M065, cellular_component, proteins 1166, annotations 810947, replaced alt. ids 0
# 2024-06-27 23:46:48,216 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M065, evaluated
# 2024-06-27 23:46:51,844 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M077, cellular_component, proteins 874, annotations 9807, replaced alt. ids 0
# 2024-06-27 23:47:13,960 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M018, evaluated
# 2024-06-27 23:47:25,348 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M022, biological_process, proteins 1455, annotations 807123, replaced alt. ids 0
# 2024-06-27 23:47:33,041 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M012, cellular_component, proteins 2308, annotations 50251, replaced alt. ids 0
# 2024-06-27 23:47:44,142 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M018, evaluated
# 2024-06-27 23:47:48,880 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M065, evaluated
# 2024-06-27 23:47:49,564 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M065, evaluated
# 2024-06-27 23:47:51,623 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M077, cellular_component, proteins 758, annotations 8495, replaced alt. ids 0
# 2024-06-27 23:47:52,295 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M077, cellular_component, proteins 874, annotations 9807, replaced alt. ids 0
# 2024-06-27 23:47:55,011 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M077, evaluated
# 2024-06-27 23:47:57,629 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M031, cellular_component, proteins 697, annotations 5038, replaced alt. ids 0
# 2024-06-27 23:48:02,648 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M012, cellular_component, proteins 2308, annotations 50251, replaced alt. ids 0
# 2024-06-27 23:48:08,585 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M077, evaluated
# 2024-06-27 23:48:10,563 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M031, cellular_component, proteins 764, annotations 5577, replaced alt. ids 0
# 2024-06-27 23:48:49,445 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M077, evaluated
# 2024-06-27 23:48:51,324 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M031, cellular_component, proteins 697, annotations 5038, replaced alt. ids 0
# 2024-06-27 23:48:54,615 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M022, evaluated
# 2024-06-27 23:48:58,847 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M031, evaluated
# 2024-06-27 23:49:00,427 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M052, cellular_component, proteins 1142, annotations 18418, replaced alt. ids 0
# 2024-06-27 23:49:15,941 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M031, evaluated
# 2024-06-27 23:49:17,369 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M077, evaluated
# 2024-06-27 23:49:17,444 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M052, cellular_component, proteins 1166, annotations 18087, replaced alt. ids 0
# 2024-06-27 23:49:20,382 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M031, cellular_component, proteins 764, annotations 5577, replaced alt. ids 0
# 2024-06-27 23:49:36,396 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M046, molecular_function, proteins 1881, annotations 148579, replaced alt. ids 7070
# 2024-06-27 23:49:55,701 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M118, evaluated
# 2024-06-27 23:50:17,057 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M031, evaluated
# 2024-06-27 23:50:19,377 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M052, cellular_component, proteins 1142, annotations 18418, replaced alt. ids 0
# 2024-06-27 23:50:19,829 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M052, evaluated
# 2024-06-27 23:50:20,515 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M132, cellular_component, proteins 22, annotations 213, replaced alt. ids 0
# 2024-06-27 23:50:23,756 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M022, molecular_function, proteins 4698, annotations 511356, replaced alt. ids 0
# 2024-06-27 23:50:25,377 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M012, evaluated
# 2024-06-27 23:50:31,037 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M052, evaluated
# 2024-06-27 23:50:31,829 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M132, cellular_component, proteins 5, annotations 57, replaced alt. ids 0
# 2024-06-27 23:50:40,361 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M031, evaluated
# 2024-06-27 23:50:41,393 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M052, cellular_component, proteins 1166, annotations 18087, replaced alt. ids 0
# 2024-06-27 23:50:42,774 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M012, evaluated
# 2024-06-27 23:51:05,947 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M118, evaluated
# 2024-06-27 23:51:13,097 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M022, evaluated
# 2024-06-27 23:51:21,420 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M052, evaluated
# 2024-06-27 23:51:21,833 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M132, cellular_component, proteins 22, annotations 213, replaced alt. ids 0
# 2024-06-27 23:51:30,251 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M132, evaluated
# 2024-06-27 23:51:32,871 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M022, cellular_component, proteins 15884, annotations 1208355, replaced alt. ids 0
# 2024-06-27 23:51:34,935 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M132, evaluated
# 2024-06-27 23:51:46,055 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M046, molecular_function, proteins 1881, annotations 148579, replaced alt. ids 7070
# 2024-06-27 23:51:47,386 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M056, cellular_component, proteins 2308, annotations 897557, replaced alt. ids 0
# 2024-06-27 23:51:49,586 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M052, evaluated
# 2024-06-27 23:51:50,040 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M132, cellular_component, proteins 5, annotations 57, replaced alt. ids 0
# 2024-06-27 23:51:51,853 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M005, cellular_component, proteins 1116, annotations 153349, replaced alt. ids 0
# 2024-06-27 23:51:53,622 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M022, evaluated
# 2024-06-27 23:51:56,856 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M005, cellular_component, proteins 1159, annotations 159472, replaced alt. ids 0
# 2024-06-27 23:52:02,700 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M056, cellular_component, proteins 2308, annotations 897557, replaced alt. ids 0
# 2024-06-27 23:52:31,913 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M132, evaluated
# 2024-06-27 23:52:49,417 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M046, biological_process, proteins 1182, annotations 802480, replaced alt. ids 12668
# 2024-06-27 23:52:54,211 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M005, cellular_component, proteins 1116, annotations 153349, replaced alt. ids 0
# 2024-06-27 23:52:57,277 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M005, evaluated
# 2024-06-27 23:53:06,061 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M086, cellular_component, proteins 1070, annotations 23106, replaced alt. ids 0
# 2024-06-27 23:53:11,142 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M132, evaluated
# 2024-06-27 23:53:12,033 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M005, evaluated
# 2024-06-27 23:53:20,403 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M086, cellular_component, proteins 974, annotations 20855, replaced alt. ids 0
# 2024-06-27 23:53:34,885 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M005, cellular_component, proteins 1159, annotations 159472, replaced alt. ids 0
# 2024-06-27 23:53:50,461 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M118, evaluated
# 2024-06-27 23:54:04,326 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M022, evaluated
# 2024-06-27 23:54:06,415 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M005, evaluated
# 2024-06-27 23:54:13,509 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M086, cellular_component, proteins 1070, annotations 23106, replaced alt. ids 0
# 2024-06-27 23:54:14,122 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M086, evaluated
# 2024-06-27 23:54:16,618 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M022, molecular_function, proteins 4698, annotations 511356, replaced alt. ids 0
# 2024-06-27 23:54:17,228 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M118, evaluated
# 2024-06-27 23:54:32,590 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M086, evaluated
# 2024-06-27 23:54:40,501 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M095, cellular_component, proteins 1133, annotations 72519, replaced alt. ids 0
# 2024-06-27 23:54:44,588 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M056, evaluated
# 2024-06-27 23:54:49,795 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M005, evaluated
# 2024-06-27 23:54:56,409 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M046, biological_process, proteins 1182, annotations 802480, replaced alt. ids 12668
# 2024-06-27 23:54:56,831 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M086, cellular_component, proteins 974, annotations 20855, replaced alt. ids 0
# 2024-06-27 23:54:57,369 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M056, evaluated
# 2024-06-27 23:54:57,756 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M095, cellular_component, proteins 1158, annotations 81552, replaced alt. ids 0
# 2024-06-27 23:55:03,264 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M086, evaluated
# 2024-06-27 23:55:05,654 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M022, evaluated
# 2024-06-27 23:55:11,964 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M046, evaluated
# 2024-06-27 23:55:18,712 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M022, biological_process, proteins 2773, annotations 1555208, replaced alt. ids 0
# 2024-06-27 23:55:27,917 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M095, cellular_component, proteins 1133, annotations 72519, replaced alt. ids 0
# 2024-06-27 23:55:38,009 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M018, molecular_function, proteins 2015, annotations 222172, replaced alt. ids 0
# 2024-06-27 23:55:41,095 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M022, evaluated
# 2024-06-27 23:55:42,105 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M046, molecular_function, proteins 2533, annotations 213320, replaced alt. ids 9617
# 2024-06-27 23:55:49,389 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M095, evaluated
# 2024-06-27 23:55:50,225 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M022, evaluated
# 2024-06-27 23:56:06,616 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M086, evaluated
# 2024-06-27 23:56:07,703 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M095, evaluated
# 2024-06-27 23:56:09,649 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M065, cellular_component, proteins 2308, annotations 1607620, replaced alt. ids 0
# 2024-06-27 23:56:12,957 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M046, molecular_function, proteins 2533, annotations 213320, replaced alt. ids 9617
# 2024-06-27 23:56:22,913 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M065, cellular_component, proteins 2308, annotations 1607620, replaced alt. ids 0
# 2024-06-27 23:56:32,638 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M095, cellular_component, proteins 1158, annotations 81552, replaced alt. ids 0
# 2024-06-27 23:56:33,937 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M095, evaluated
# 2024-06-27 23:56:50,069 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M046, biological_process, proteins 1362, annotations 880229, replaced alt. ids 15320
# 2024-06-27 23:57:11,567 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M118, evaluated
# 2024-06-27 23:57:12,313 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M045, cellular_component, proteins 1139, annotations 193995, replaced alt. ids 0
# 2024-06-27 23:57:29,743 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M045, cellular_component, proteins 1165, annotations 184720, replaced alt. ids 0
# 2024-06-27 23:57:41,157 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M022, evaluated
# 2024-06-27 23:57:44,455 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M095, evaluated
# 2024-06-27 23:57:59,873 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M045, cellular_component, proteins 1139, annotations 193995, replaced alt. ids 0
# 2024-06-27 23:58:02,387 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M118, evaluated
# 2024-06-27 23:58:08,601 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M065, evaluated
# 2024-06-27 23:58:11,924 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M022, biological_process, proteins 2773, annotations 1555208, replaced alt. ids 0
# 2024-06-27 23:58:12,499 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M077, cellular_component, proteins 1632, annotations 18302, replaced alt. ids 0
# 2024-06-27 23:58:21,796 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M045, evaluated
# 2024-06-27 23:58:35,654 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M046, biological_process, proteins 1362, annotations 880229, replaced alt. ids 15320
# 2024-06-27 23:58:38,683 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M022, cellular_component, proteins 15884, annotations 1208355, replaced alt. ids 0
# 2024-06-27 23:58:39,938 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M045, evaluated
# 2024-06-27 23:59:04,266 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M118, evaluated
# 2024-06-27 23:59:07,107 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M045, evaluated
# 2024-06-27 23:59:08,718 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M046, evaluated
# 2024-06-27 23:59:09,419 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M045, cellular_component, proteins 1165, annotations 184720, replaced alt. ids 0
# 2024-06-27 23:59:12,419 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M065, evaluated
# 2024-06-27 23:59:13,632 [WARNI] Empty prediction! Check format or overlap with ground truth
# 2024-06-27 23:59:13,642 [WARNI] Prediction: /data/yisupeng/sharing/cafa4/all_models/M083, not evaluated
# 2024-06-27 23:59:15,780 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M077, cellular_component, proteins 1632, annotations 18302, replaced alt. ids 0
# 2024-06-27 23:59:25,122 [WARNI] Empty prediction! Check format or overlap with ground truth
# 2024-06-27 23:59:25,127 [WARNI] Prediction: /data/yisupeng/sharing/cafa4/all_models/M083, not evaluated
# 2024-06-27 23:59:38,288 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M018, molecular_function, proteins 2015, annotations 222172, replaced alt. ids 0
# 2024-06-27 23:59:57,632 [WARNI] Empty prediction! Check format or overlap with ground truth
# 2024-06-27 23:59:57,643 [WARNI] Prediction: /data/yisupeng/sharing/cafa4/all_models/M083, not evaluated
# 2024-06-28 00:00:23,104 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M045, evaluated
# 2024-06-28 00:00:24,353 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M022, evaluated
# 2024-06-28 00:00:31,838 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M046, evaluated
# 2024-06-28 00:00:35,203 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M120, cellular_component, proteins 1142, annotations 509731, replaced alt. ids 0
# 2024-06-28 00:00:48,090 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M120, cellular_component, proteins 1166, annotations 520511, replaced alt. ids 0
# 2024-06-28 00:01:00,902 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M046, molecular_function, proteins 4414, annotations 361899, replaced alt. ids 16687
# 2024-06-28 00:01:01,991 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M077, evaluated
# 2024-06-28 00:01:04,090 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M031, cellular_component, proteins 1461, annotations 10615, replaced alt. ids 0
# 2024-06-28 00:01:09,872 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M022, biological_process, proteins 24010, annotations 14499206, replaced alt. ids 0
# 2024-06-28 00:01:15,281 [WARNI] Empty prediction! Check format or overlap with ground truth
# 2024-06-28 00:01:15,284 [WARNI] Prediction: /data/yisupeng/sharing/cafa4/all_models/M083, not evaluated
# 2024-06-28 00:01:17,089 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M018, biological_process, proteins 1317, annotations 808167, replaced alt. ids 0
# 2024-06-28 00:01:28,080 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M120, cellular_component, proteins 1142, annotations 509731, replaced alt. ids 0
# 2024-06-28 00:01:49,649 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M018, evaluated
# 2024-06-28 00:01:54,206 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M120, evaluated
# 2024-06-28 00:02:05,648 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M120, evaluated
# 2024-06-28 00:02:13,152 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M012, molecular_function, proteins 1663, annotations 31426, replaced alt. ids 0
# 2024-06-28 00:02:25,801 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M077, evaluated
# 2024-06-28 00:02:29,128 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M031, cellular_component, proteins 1461, annotations 10615, replaced alt. ids 0
# 2024-06-28 00:02:46,365 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M076, cellular_component, proteins 822, annotations 111582, replaced alt. ids 0
# 2024-06-28 00:02:46,728 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M120, evaluated
# 2024-06-28 00:02:48,602 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M120, cellular_component, proteins 1166, annotations 520511, replaced alt. ids 0
# 2024-06-28 00:03:02,297 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M076, cellular_component, proteins 947, annotations 131017, replaced alt. ids 0
# 2024-06-28 00:03:40,759 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M076, cellular_component, proteins 822, annotations 111582, replaced alt. ids 0
# 2024-06-28 00:03:53,641 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M120, evaluated
# 2024-06-28 00:04:03,694 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M031, evaluated
# 2024-06-28 00:04:04,930 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M046, evaluated
# 2024-06-28 00:04:05,492 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M052, cellular_component, proteins 2308, annotations 36505, replaced alt. ids 0
# 2024-06-28 00:04:07,250 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M076, evaluated
# 2024-06-28 00:04:08,691 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M040, cellular_component, proteins 1043, annotations 14176, replaced alt. ids 0
# 2024-06-28 00:04:26,546 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M076, evaluated
# 2024-06-28 00:04:28,167 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M040, cellular_component, proteins 1022, annotations 15618, replaced alt. ids 0
# 2024-06-28 00:04:42,793 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M076, cellular_component, proteins 947, annotations 131017, replaced alt. ids 0
# 2024-06-28 00:04:59,782 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M076, evaluated
# 2024-06-28 00:05:01,290 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M040, cellular_component, proteins 1043, annotations 14176, replaced alt. ids 0
# 2024-06-28 00:05:04,852 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M018, biological_process, proteins 1317, annotations 808167, replaced alt. ids 0
# 2024-06-28 00:05:16,190 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M040, evaluated
# 2024-06-28 00:05:17,131 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M138, cellular_component, proteins 1012, annotations 13137, replaced alt. ids 0
# 2024-06-28 00:05:44,559 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M046, evaluated
# 2024-06-28 00:05:47,513 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M031, evaluated
# 2024-06-28 00:05:48,030 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M076, evaluated
# 2024-06-28 00:05:48,928 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M052, cellular_component, proteins 2308, annotations 36505, replaced alt. ids 0
# 2024-06-28 00:05:49,272 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M040, cellular_component, proteins 1022, annotations 15618, replaced alt. ids 0
# 2024-06-28 00:05:53,790 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M040, evaluated
# 2024-06-28 00:05:54,711 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M138, cellular_component, proteins 1034, annotations 14491, replaced alt. ids 0
# 2024-06-28 00:06:10,580 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M052, evaluated
# 2024-06-28 00:06:11,747 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M132, cellular_component, proteins 27, annotations 270, replaced alt. ids 0
# 2024-06-28 00:06:13,236 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M040, evaluated
# 2024-06-28 00:06:13,386 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M018, molecular_function, proteins 2682, annotations 304059, replaced alt. ids 0
# 2024-06-28 00:06:14,019 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M138, cellular_component, proteins 1012, annotations 13137, replaced alt. ids 0
# 2024-06-28 00:06:24,058 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M138, evaluated
# 2024-06-28 00:06:43,215 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M046, evaluated
# 2024-06-28 00:06:48,085 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M018, evaluated
# 2024-06-28 00:07:02,284 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M040, evaluated
# 2024-06-28 00:07:03,220 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M138, cellular_component, proteins 1034, annotations 14491, replaced alt. ids 0
# 2024-06-28 00:07:11,199 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M018, molecular_function, proteins 2682, annotations 304059, replaced alt. ids 0
# 2024-06-28 00:07:11,525 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M012, molecular_function, proteins 1663, annotations 31426, replaced alt. ids 0
# 2024-06-28 00:07:12,352 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M046, evaluated
# 2024-06-28 00:07:14,395 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M138, evaluated
# 2024-06-28 00:07:20,208 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M138, evaluated
# 2024-06-28 00:08:03,760 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M018, biological_process, proteins 1454, annotations 894475, replaced alt. ids 0
# 2024-06-28 00:08:18,217 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M138, evaluated
# 2024-06-28 00:08:44,695 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M052, evaluated
# 2024-06-28 00:08:45,316 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M132, cellular_component, proteins 27, annotations 270, replaced alt. ids 0
# 2024-06-28 00:09:08,155 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M132, evaluated
# 2024-06-28 00:09:30,450 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M005, cellular_component, proteins 2275, annotations 312821, replaced alt. ids 0
# 2024-06-28 00:09:36,142 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M012, evaluated
# 2024-06-28 00:09:36,194 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M032, cellular_component, proteins 1142, annotations 47263, replaced alt. ids 0
# 2024-06-28 00:09:42,884 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M046, evaluated
# 2024-06-28 00:10:12,168 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M032, cellular_component, proteins 1166, annotations 47806, replaced alt. ids 0
# 2024-06-28 00:10:19,689 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M032, cellular_component, proteins 1142, annotations 47263, replaced alt. ids 0
# 2024-06-28 00:10:34,131 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M018, biological_process, proteins 1454, annotations 894475, replaced alt. ids 0
# 2024-06-28 00:10:38,728 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M018, evaluated
# 2024-06-28 00:10:43,849 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M032, evaluated
# 2024-06-28 00:10:45,317 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M104, cellular_component, proteins 24, annotations 1297, replaced alt. ids 0
# 2024-06-28 00:11:00,405 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M056, molecular_function, proteins 2016, annotations 1116518, replaced alt. ids 0
# 2024-06-28 00:11:05,520 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M032, cellular_component, proteins 1166, annotations 47806, replaced alt. ids 0
# 2024-06-28 00:11:18,109 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M032, evaluated
# 2024-06-28 00:11:19,414 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M104, cellular_component, proteins 9, annotations 622, replaced alt. ids 0
# 2024-06-28 00:11:20,085 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M012, evaluated
# 2024-06-28 00:11:23,007 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M032, evaluated
# 2024-06-28 00:11:24,275 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M104, cellular_component, proteins 24, annotations 1297, replaced alt. ids 0
# 2024-06-28 00:11:30,505 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M132, evaluated
# 2024-06-28 00:11:33,076 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M012, biological_process, proteins 1150, annotations 107393, replaced alt. ids 0
# 2024-06-28 00:11:51,723 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M005, cellular_component, proteins 2275, annotations 312821, replaced alt. ids 0
# 2024-06-28 00:12:01,812 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M104, evaluated
# 2024-06-28 00:12:14,244 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M104, evaluated
# 2024-06-28 00:12:15,489 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M005, evaluated
# 2024-06-28 00:12:17,961 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M032, evaluated
# 2024-06-28 00:12:19,348 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M104, cellular_component, proteins 9, annotations 622, replaced alt. ids 0
# 2024-06-28 00:12:23,634 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M086, cellular_component, proteins 2044, annotations 43961, replaced alt. ids 0
# 2024-06-28 00:12:31,950 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M104, evaluated
# 2024-06-28 00:12:49,909 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M056, molecular_function, proteins 2016, annotations 1116518, replaced alt. ids 0
# 2024-06-28 00:13:25,611 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M022, evaluated
# 2024-06-28 00:13:27,987 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M104, evaluated
# 2024-06-28 00:13:32,325 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M044, cellular_component, proteins 1138, annotations 196457, replaced alt. ids 0
# 2024-06-28 00:13:35,190 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M044, cellular_component, proteins 21, annotations 4351, replaced alt. ids 0
# 2024-06-28 00:13:35,580 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M022, evaluated
# 2024-06-28 00:13:58,490 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M044, cellular_component, proteins 1138, annotations 196457, replaced alt. ids 0
# 2024-06-28 00:13:59,284 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M046, molecular_function, proteins 4414, annotations 361899, replaced alt. ids 16687
# 2024-06-28 00:14:02,733 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M022, evaluated
# 2024-06-28 00:14:35,958 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M018, evaluated
# 2024-06-28 00:14:36,904 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M046, biological_process, proteins 2544, annotations 1682709, replaced alt. ids 27988
# 2024-06-28 00:14:37,678 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M046, cellular_component, proteins 14739, annotations 1287576, replaced alt. ids 28512
# 2024-06-28 00:14:38,145 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M086, evaluated
# 2024-06-28 00:14:42,919 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M044, evaluated
# 2024-06-28 00:14:44,082 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M108, cellular_component, proteins 1010, annotations 13215, replaced alt. ids 0
# 2024-06-28 00:14:44,286 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M044, evaluated
# 2024-06-28 00:14:45,187 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M108, cellular_component, proteins 1039, annotations 14280, replaced alt. ids 0
# 2024-06-28 00:14:45,860 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M044, cellular_component, proteins 21, annotations 4351, replaced alt. ids 0
# 2024-06-28 00:14:59,458 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M005, evaluated
# 2024-06-28 00:15:05,399 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M044, evaluated
# 2024-06-28 00:15:06,107 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M108, cellular_component, proteins 1010, annotations 13215, replaced alt. ids 0
# 2024-06-28 00:15:06,795 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M095, cellular_component, proteins 2291, annotations 154071, replaced alt. ids 0
# 2024-06-28 00:15:07,316 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M086, cellular_component, proteins 2044, annotations 43961, replaced alt. ids 0
# 2024-06-28 00:15:14,520 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M012, biological_process, proteins 1150, annotations 107393, replaced alt. ids 0
# 2024-06-28 00:15:52,482 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M108, evaluated
# 2024-06-28 00:15:58,441 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M044, evaluated
# 2024-06-28 00:15:59,140 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M108, cellular_component, proteins 1039, annotations 14280, replaced alt. ids 0
# 2024-06-28 00:15:59,559 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M064, cellular_component, proteins 795, annotations 16813, replaced alt. ids 0
# 2024-06-28 00:16:03,255 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M108, evaluated
# 2024-06-28 00:16:09,518 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M064, cellular_component, proteins 803, annotations 11934, replaced alt. ids 0
# 2024-06-28 00:16:12,552 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M018, evaluated
# 2024-06-28 00:16:14,665 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M108, evaluated
# 2024-06-28 00:16:19,873 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M064, cellular_component, proteins 795, annotations 16813, replaced alt. ids 0
# 2024-06-28 00:16:33,038 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M012, molecular_function, proteins 2399, annotations 57075, replaced alt. ids 0
# 2024-06-28 00:16:43,372 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M046, evaluated
# 2024-06-28 00:17:11,212 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M018, evaluated
# 2024-06-28 00:17:11,977 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M108, evaluated
# 2024-06-28 00:17:13,221 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M018, evaluated
# 2024-06-28 00:17:15,772 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M018, molecular_function, proteins 4697, annotations 526231, replaced alt. ids 0
# 2024-06-28 00:17:17,640 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M064, evaluated
# 2024-06-28 00:17:18,439 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M064, cellular_component, proteins 803, annotations 11934, replaced alt. ids 0
# 2024-06-28 00:17:19,817 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M027, cellular_component, proteins 1134, annotations 19449, replaced alt. ids 0
# 2024-06-28 00:17:23,326 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M064, evaluated
# 2024-06-28 00:17:24,870 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M027, cellular_component, proteins 1118, annotations 17850, replaced alt. ids 0
# 2024-06-28 00:17:25,567 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M064, evaluated
# 2024-06-28 00:17:27,444 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M027, cellular_component, proteins 1118, annotations 17850, replaced alt. ids 0
# 2024-06-28 00:17:36,774 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M022, evaluated
# 2024-06-28 00:17:36,875 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M012, molecular_function, proteins 2399, annotations 57075, replaced alt. ids 0
# 2024-06-28 00:17:42,540 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M012, biological_process, proteins 1331, annotations 151226, replaced alt. ids 0
# 2024-06-28 00:17:42,988 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M056, evaluated
# 2024-06-28 00:17:50,650 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M056, evaluated
# 2024-06-28 00:17:52,874 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M018, evaluated
# 2024-06-28 00:18:24,894 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M027, evaluated
# 2024-06-28 00:18:26,459 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M086, evaluated
# 2024-06-28 00:18:27,507 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M046, biological_process, proteins 2544, annotations 1682709, replaced alt. ids 27988
# 2024-06-28 00:18:27,570 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M095, evaluated
# 2024-06-28 00:18:30,121 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M027, evaluated
# 2024-06-28 00:18:33,147 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M064, evaluated
# 2024-06-28 00:18:33,234 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M121, cellular_component, proteins 378, annotations 21886, replaced alt. ids 0
# 2024-06-28 00:18:34,562 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M027, cellular_component, proteins 1134, annotations 19449, replaced alt. ids 0
# 2024-06-28 00:18:36,757 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M012, biological_process, proteins 1331, annotations 151226, replaced alt. ids 0
# 2024-06-28 00:18:37,663 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M121, cellular_component, proteins 505, annotations 31293, replaced alt. ids 0
# 2024-06-28 00:18:37,709 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M027, evaluated
# 2024-06-28 00:18:46,879 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M121, cellular_component, proteins 378, annotations 21886, replaced alt. ids 0
# 2024-06-28 00:18:53,670 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M095, cellular_component, proteins 2291, annotations 154071, replaced alt. ids 0
# 2024-06-28 00:19:06,220 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M065, molecular_function, proteins 2016, annotations 1324770, replaced alt. ids 0
# 2024-06-28 00:19:14,619 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M065, molecular_function, proteins 2016, annotations 1324770, replaced alt. ids 0
# 2024-06-28 00:19:35,945 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M121, evaluated
# 2024-06-28 00:19:36,989 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M141, cellular_component, proteins 1139, annotations 4669, replaced alt. ids 0
# 2024-06-28 00:19:43,705 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M121, evaluated
# 2024-06-28 00:19:44,454 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M141, cellular_component, proteins 1137, annotations 4457, replaced alt. ids 0
# 2024-06-28 00:19:47,006 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M027, evaluated
# 2024-06-28 00:19:55,519 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M045, cellular_component, proteins 2304, annotations 378715, replaced alt. ids 0
# 2024-06-28 00:19:57,007 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M121, cellular_component, proteins 505, annotations 31293, replaced alt. ids 0
# 2024-06-28 00:20:03,399 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M121, evaluated
# 2024-06-28 00:20:04,221 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M141, cellular_component, proteins 1137, annotations 4457, replaced alt. ids 0
# 2024-06-28 00:20:59,636 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M141, evaluated
# 2024-06-28 00:21:07,691 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M141, evaluated
# 2024-06-28 00:21:14,044 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M092, cellular_component, proteins 1166, annotations 31251, replaced alt. ids 0
# 2024-06-28 00:21:17,811 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M012, evaluated
# 2024-06-28 00:21:17,834 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M121, evaluated
# ...
# 2024-06-28 01:45:36,048 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M035, evaluated
# 2024-06-28 01:45:43,943 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M114, cellular_component, proteins 987, annotations 353524, replaced alt. ids 192
# 2024-06-28 01:45:51,492 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M114, cellular_component, proteins 987, annotations 353524, replaced alt. ids 192
# 2024-06-28 01:45:52,698 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M033, cellular_component, proteins 2308, annotations 95069, replaced alt. ids 0
# 2024-06-28 01:45:53,124 [WARNI] Empty prediction! Check format or overlap with ground truth
# 2024-06-28 01:45:53,133 [WARNI] Prediction: /data/yisupeng/sharing/cafa4/all_models/M084, not evaluated
# 2024-06-28 01:45:56,211 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M065, biological_process, proteins 2773, annotations 2485417, replaced alt. ids 0
# 2024-06-28 01:45:57,569 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M076, evaluated
# 2024-06-28 01:46:01,145 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M040, molecular_function, proteins 1627, annotations 19216, replaced alt. ids 0
# 2024-06-28 01:46:11,016 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M095, evaluated
# 2024-06-28 01:46:31,216 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M095, evaluated
# 2024-06-28 01:46:47,036 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M114, evaluated
# 2024-06-28 01:46:47,168 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M114, evaluated
# 2024-06-28 01:46:47,742 [WARNI] Empty prediction! Check format or overlap with ground truth
# 2024-06-28 01:46:47,760 [WARNI] Prediction: /data/yisupeng/sharing/cafa4/all_models/M079, not evaluated
# 2024-06-28 01:46:48,340 [WARNI] Empty prediction! Check format or overlap with ground truth
# 2024-06-28 01:46:48,343 [WARNI] Prediction: /data/yisupeng/sharing/cafa4/all_models/M079, not evaluated
# 2024-06-28 01:46:50,729 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M114, cellular_component, proteins 1084, annotations 388664, replaced alt. ids 198
# 2024-06-28 01:47:24,096 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M098, cellular_component, proteins 890, annotations 79101, replaced alt. ids 0
# 2024-06-28 01:47:27,842 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M098, cellular_component, proteins 890, annotations 79101, replaced alt. ids 0
# 2024-06-28 01:47:37,649 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M077, evaluated
# 2024-06-28 01:47:42,956 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M031, molecular_function, proteins 2811, annotations 43518, replaced alt. ids 0
# 2024-06-28 01:47:48,425 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M114, cellular_component, proteins 1084, annotations 388664, replaced alt. ids 198
# 2024-06-28 01:47:51,688 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M114, evaluated
# 2024-06-28 01:47:52,262 [WARNI] Empty prediction! Check format or overlap with ground truth
# 2024-06-28 01:47:52,267 [WARNI] Prediction: /data/yisupeng/sharing/cafa4/all_models/M079, not evaluated
# 2024-06-28 01:48:21,061 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M045, biological_process, proteins 1315, annotations 1577426, replaced alt. ids 0
# 2024-06-28 01:48:25,019 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M098, cellular_component, proteins 951, annotations 87074, replaced alt. ids 0
# 2024-06-28 01:48:25,858 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M045, biological_process, proteins 1315, annotations 1577426, replaced alt. ids 0
# 2024-06-28 01:48:28,090 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M033, cellular_component, proteins 2308, annotations 95069, replaced alt. ids 0
# 2024-06-28 01:48:35,381 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M098, evaluated
# 2024-06-28 01:48:37,129 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M051, cellular_component, proteins 1142, annotations 27720, replaced alt. ids 0
# 2024-06-28 01:48:39,457 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M033, evaluated
# 2024-06-28 01:48:40,504 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M137, cellular_component, proteins 2105, annotations 27689, replaced alt. ids 0
# 2024-06-28 01:48:43,474 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M095, evaluated
# 2024-06-28 01:48:43,631 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M098, evaluated
# 2024-06-28 01:48:45,661 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M051, cellular_component, proteins 1142, annotations 27720, replaced alt. ids 0
# 2024-06-28 01:48:59,850 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M114, evaluated
# 2024-06-28 01:49:00,685 [WARNI] Empty prediction! Check format or overlap with ground truth
# 2024-06-28 01:49:00,686 [WARNI] Prediction: /data/yisupeng/sharing/cafa4/all_models/M079, not evaluated
# 2024-06-28 01:49:36,347 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M098, cellular_component, proteins 951, annotations 87074, replaced alt. ids 0
# 2024-06-28 01:49:38,571 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M098, evaluated
# 2024-06-28 01:49:40,752 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M051, cellular_component, proteins 1166, annotations 27025, replaced alt. ids 0
# 2024-06-28 01:49:52,272 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M051, evaluated
# 2024-06-28 01:50:03,294 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M051, evaluated
# 2024-06-28 01:50:18,458 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M045, molecular_function, proteins 2681, annotations 385261, replaced alt. ids 0
# 2024-06-28 01:50:26,026 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M095, evaluated
# 2024-06-28 01:50:45,021 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M098, evaluated
# 2024-06-28 01:50:47,364 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M051, cellular_component, proteins 1166, annotations 27025, replaced alt. ids 0
# 2024-06-28 01:50:48,940 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M004, cellular_component, proteins 1142, annotations 131881, replaced alt. ids 0
# 2024-06-28 01:50:54,631 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M004, cellular_component, proteins 1142, annotations 131881, replaced alt. ids 0
# 2024-06-28 01:50:54,637 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M051, evaluated
# 2024-06-28 01:50:55,349 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M137, evaluated
# 2024-06-28 01:50:56,880 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M102, cellular_component, proteins 33, annotations 1920, replaced alt. ids 0
# 2024-06-28 01:51:03,786 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M138, evaluated
# 2024-06-28 01:51:22,470 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M033, evaluated
# 2024-06-28 01:51:23,704 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M137, cellular_component, proteins 2105, annotations 27689, replaced alt. ids 0
# 2024-06-28 01:51:28,153 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M065, evaluated
# 2024-06-28 01:51:29,043 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M086, evaluated
# 2024-06-28 01:51:41,955 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M004, cellular_component, proteins 1166, annotations 134254, replaced alt. ids 0
# 2024-06-28 01:51:42,994 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M086, evaluated
# 2024-06-28 01:51:43,517 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M045, molecular_function, proteins 2681, annotations 385261, replaced alt. ids 0
# 2024-06-28 01:51:43,585 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M065, evaluated
# 2024-06-28 01:51:48,961 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M077, cellular_component, proteins 12734, annotations 180754, replaced alt. ids 0
# 2024-06-28 01:51:51,634 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M051, evaluated
# 2024-06-28 01:51:54,799 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M004, evaluated
# 2024-06-28 01:51:55,429 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M077, biological_process, proteins 1877, annotations 71794, replaced alt. ids 0
# 2024-06-28 01:51:56,214 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M004, evaluated
# 2024-06-28 01:52:05,571 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M068, cellular_component, proteins 1078, annotations 29637, replaced alt. ids 0
# 2024-06-28 01:52:06,569 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M068, cellular_component, proteins 1078, annotations 29637, replaced alt. ids 0
# 2024-06-28 01:52:12,820 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M095, biological_process, proteins 1446, annotations 478541, replaced alt. ids 0
# 2024-06-28 01:52:26,238 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M095, biological_process, proteins 1446, annotations 478541, replaced alt. ids 0
# 2024-06-28 01:52:40,311 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M004, cellular_component, proteins 1166, annotations 134254, replaced alt. ids 0
# 2024-06-28 01:52:55,130 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M004, evaluated
# 2024-06-28 01:53:06,784 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M068, cellular_component, proteins 1107, annotations 30484, replaced alt. ids 0
# 2024-06-28 01:53:18,565 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M040, evaluated
# 2024-06-28 01:53:21,833 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M138, molecular_function, proteins 1021, annotations 12269, replaced alt. ids 0
# 2024-06-28 01:53:22,311 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M068, evaluated
# 2024-06-28 01:53:25,078 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M068, evaluated
# 2024-06-28 01:53:32,958 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M055, cellular_component, proteins 1142, annotations 98366, replaced alt. ids 0
# 2024-06-28 01:53:35,404 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M102, evaluated
# 2024-06-28 01:53:35,836 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M055, cellular_component, proteins 1142, annotations 98366, replaced alt. ids 0
# 2024-06-28 01:53:50,182 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M004, evaluated
# 2024-06-28 01:54:00,082 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M068, cellular_component, proteins 1107, annotations 30484, replaced alt. ids 0
# 2024-06-28 01:54:00,503 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M032, molecular_function, proteins 2016, annotations 71142, replaced alt. ids 0
# 2024-06-28 01:54:06,590 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M119, cellular_component, proteins 1966, annotations 109866, replaced alt. ids 0
# 2024-06-28 01:54:16,778 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M137, evaluated
# 2024-06-28 01:54:18,587 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M102, cellular_component, proteins 33, annotations 1920, replaced alt. ids 0
# 2024-06-28 01:54:21,788 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M068, evaluated
# 2024-06-28 01:54:33,249 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M055, cellular_component, proteins 1166, annotations 93094, replaced alt. ids 0
# 2024-06-28 01:54:51,676 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M055, evaluated
# 2024-06-28 01:54:54,058 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M055, evaluated
# 2024-06-28 01:54:58,317 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M111, cellular_component, proteins 973, annotations 16089, replaced alt. ids 0
# 2024-06-28 01:55:00,762 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M111, cellular_component, proteins 973, annotations 16089, replaced alt. ids 0
# 2024-06-28 01:55:19,050 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M068, evaluated
# 2024-06-28 01:55:31,042 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M055, cellular_component, proteins 1166, annotations 93094, replaced alt. ids 0
# 2024-06-28 01:56:03,456 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M055, evaluated
# 2024-06-28 01:56:09,750 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M111, cellular_component, proteins 1016, annotations 18215, replaced alt. ids 0
# 2024-06-28 01:56:19,002 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M111, evaluated
# 2024-06-28 01:56:19,834 [WARNI] Empty prediction! Check format or overlap with ground truth
# 2024-06-28 01:56:19,842 [WARNI] Prediction: /data/yisupeng/sharing/cafa4/all_models/M025, not evaluated
# 2024-06-28 01:56:21,036 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M042, cellular_component, proteins 991, annotations 13206, replaced alt. ids 0
# 2024-06-28 01:56:23,024 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M111, evaluated
# 2024-06-28 01:56:24,063 [WARNI] Empty prediction! Check format or overlap with ground truth
# 2024-06-28 01:56:24,080 [WARNI] Prediction: /data/yisupeng/sharing/cafa4/all_models/M025, not evaluated
# 2024-06-28 01:56:25,523 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M042, cellular_component, proteins 991, annotations 13206, replaced alt. ids 0
# 2024-06-28 01:56:31,550 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M045, evaluated
# 2024-06-28 01:56:53,011 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M055, evaluated
# 2024-06-28 01:56:59,961 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M111, cellular_component, proteins 1016, annotations 18215, replaced alt. ids 0
# 2024-06-28 01:57:16,237 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M119, evaluated
# 2024-06-28 01:57:26,413 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M090, cellular_component, proteins 2308, annotations 48196, replaced alt. ids 0
# 2024-06-28 01:57:31,020 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M111, evaluated
# 2024-06-28 01:57:31,615 [WARNI] Empty prediction! Check format or overlap with ground truth
# 2024-06-28 01:57:31,617 [WARNI] Prediction: /data/yisupeng/sharing/cafa4/all_models/M025, not evaluated
# 2024-06-28 01:57:32,826 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M042, cellular_component, proteins 985, annotations 14834, replaced alt. ids 0
# 2024-06-28 01:57:41,061 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M102, evaluated
# 2024-06-28 01:57:42,393 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M045, evaluated
# 2024-06-28 01:57:42,941 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M042, evaluated
# 2024-06-28 01:57:44,340 [WARNI] Empty prediction! Check format or overlap with ground truth
# 2024-06-28 01:57:44,441 [WARNI] Prediction: /data/yisupeng/sharing/cafa4/all_models/M083, not evaluated
# 2024-06-28 01:57:49,205 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M042, evaluated
# 2024-06-28 01:58:01,379 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M013, cellular_component, proteins 1142, annotations 22447, replaced alt. ids 0
# 2024-06-28 01:58:05,606 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M119, cellular_component, proteins 1966, annotations 109866, replaced alt. ids 0
# 2024-06-28 01:58:05,644 [INFO ] Prediction: /data/yisupeng/sharing/cafa4/all_models/M013, cellular_component, proteins 1142, annotations 22447, replaced alt. ids 0

# %% [markdown]
# ## Test the figures

# %%
[dir_list = os.listdir(results_path)
    
    [cumulate = True
    add_extreme_points = True
    coverage_threshold = 0.3
    axis_title_dict = {'pr': 'Precision', 'rc': 'Recall', 'f': 'F-score', 'pr_w': 'Weighted Precision', 'rc_w': 'Weighted Recall', 'f_w': 'Weighted F-score', 'mi': 'Misinformation (Unweighted)', 'ru': 'Remaining Uncertainty (Unweighted)', 'mi_w': 'Misinformation', 'ru_w': 'Remaining Uncertainty', 's': 'S-score', 'pr_micro': 'Precision (Micro)', 'rc_micro': 'Recall (Micro)', 'f_micro': 'F-score (Micro)', 'pr_micro_w': 'Weighted Precision (Micro)', 'rc_micro_w': 'Weighted Recall (Micro)', 'f_micro_w': 'Weighted F-score (Micro)'}
    ontology_dict = {'biological_process': 'BPO', 'molecular_function': 'MFO', 'cellular_component': 'CCO'}
    
    if not os.path.exists(out_path):
        os.mkdir(out_path)
    
    dir_list.remove('bpo_all_type3')
    for file in dir_list:
        df_file = results_path + file +"/evaluation_all.tsv"
        df = pd.read_csv(df_file, sep="\t")
        out_folder = out_path + file
        if not os.path.exists(out_folder):
            os.mkdir(out_folder)
            
        
        df = pd.read_csv(df_file, sep="\t")
        
        # Set method information (optional)
        if names_file is None:
            df['group'] = df['filename']
            df['label'] = df['filename']
            df['is_baseline'] = False
        else:
            methods = pd.read_csv(names_file, sep = "\t", header=0)
            df = pd.merge(df, methods, on='filename', how='left')
            df['group'].fillna(df['filename'], inplace=True)
            df['label'].fillna(df['filename'], inplace=True)
            if 'is_baseline' not in df:
                df['is_baseline'] = False
            else:
                df['is_baseline'].fillna(False, inplace=True)
            # print(methods)
        #df = df.drop(columns='filename').set_index(['group', 'label', 'ns', 'tau'])
        df = df.set_index(['group_unique', 'label', 'ns', 'filename','tau'])
        
        # Filter by coverage
        df = df[df['cov'] >= coverage_threshold]
        
        # Assign colors based on group
        cmap = plt.get_cmap('tab20')
        df['colors'] = df.index.get_level_values('group_unique')
        df['colors'] = pd.factorize(df['colors'])[0]
        df['colors'] = df['colors'].apply(lambda x: cmap.colors[x % len(cmap.colors)])
        
        index_best = df.groupby(level=['group_unique', 'ns'])[metric].idxmax() if metric in ['f', 'f_w', 'f_micro', 'f_micro_w'] else df.groupby(['group_unique', 'ns'])[metric].idxmin()
        
        # Filter the dataframe for the best methods
        df_methods = df.reset_index('tau').loc[[ele[:-1] for ele in index_best], ['tau', 'cov', 'colors'] + cols + [metric]].sort_index()

        # Makes the curves monotonic. Cumulative max on the last column of the cols variable, e.g. "pr" --> precision
        if cumulate:
            if metric in ['f', 'f_w', 'f_micro', 'f_micro_w']:
                df_methods[cols[-1]] = df_methods.groupby(level=['label', 'ns'])[cols[-1]].cummax()
            else:
                df_methods[cols[-1]] = df_methods.groupby(level=['label', 'ns'])[cols[-1]].cummin()


        # Save to file
        df_methods.drop(columns=['colors']).to_csv('{}/fig_{}.tsv'.format(out_folder, metric), float_format="%.3f", sep="\t")
        
        # Add first last points to precision and recall curves to improve APS calculation
        def add_points(df_):
            df_ = pd.concat([df_.iloc[0:1], df_])
            df_.iloc[0, df_.columns.get_indexer(['tau', cols[0], cols[1]])] = [0, 1, 0]  # tau, rc, pr
            df_ = pd.concat([df_, df_.iloc[-1:]])
            df_.iloc[-1, df_.columns.get_indexer(['tau', cols[0], cols[1]])] = [1.1, 0, 1]
            return df_

        if metric.startswith('f') and add_extreme_points:
            df_methods = df_methods.reset_index().groupby(['group_unique', 'label', 'ns'], as_index=False).apply(add_points).set_index(['group_unique', 'label', 'ns'])
        
        # Filter the dataframe for the best method and threshold
        df_best = df.loc[index_best, ['cov', 'colors'] + cols + [metric]]
        
        # Calculate average precision score 
        if metric.startswith('f'):
            df_best['aps'] = df_methods.groupby(level=['group_unique', 'label', 'ns'])[[cols[0], cols[1]]].apply(lambda x: (x[cols[0]].diff(-1).shift(1) * x[cols[1]]).sum())

        # Calculate the max coverage across all thresholds
        df_best['max_cov'] = df_methods.groupby(level=['group_unique', 'label', 'ns'])['cov'].max()
        
        # Set a label column for the plot legend
        df_best['label'] = df_best.index.get_level_values('label')
        if 'aps' not in df_best.columns:
            df_best['label'] = df_best.agg(lambda x: f"{x['label']} ({metric.upper()}={x[metric]:.3f} C={x['max_cov']:.3f})", axis=1)
        else:
            df_best['label'] = df_best.agg(lambda x: f"{x['label']} ({metric.upper()}={x[metric]:.3f} APS={x['aps']:.3f} C={x['max_cov']:.3f})", axis=1)
        
        # Generate the figures
        plt.rcParams.update({'font.size': 22, 'legend.fontsize': 18})

        # F-score contour lines
        x = np.arange(0.01, 1, 0.01)
        y = np.arange(0.01, 1, 0.01)
        X, Y = np.meshgrid(x, y)
        Z = 2 * X * Y / (X + Y)

        
        for ns, df_g in df_best.groupby(level='ns'):
            fig, ax = plt.subplots(figsize=(15, 15))

             # Contour lines. At the moment they are provided only for the F-score
            if metric.startswith('f'):
                CS = ax.contour(X, Y, Z, np.arange(0.1, 1.0, 0.1), colors='gray')
                ax.clabel(CS, inline=True) #, fontsize=10)

            cnt = 0
            # Iterate methods
            for i, (index, row) in enumerate(df_g.sort_values(by=[metric, 'max_cov'], ascending=[False if metric.startswith('f') else True, False]).iterrows()):
                
                #data = df_methods.loc[index[:-1]]
                data = df_methods.loc[index[:-2]]
                print(row[cols[0]], row[cols[1]])

                # Precision-recall or mi-ru curves
                ax.plot(data[cols[0]], data[cols[1]], color=row['colors'], label=row['label'], lw=2, zorder=500-i)

                # F-max or S-min dots
                ax.plot(row[cols[0]], row[cols[1]], color=row['colors'], marker='o', markersize=12, mfc='none', zorder=1000-i)
                ax.plot(row[cols[0]], row[cols[1]], color=row['colors'], marker='o', markersize=6, zorder=1000-i)

                cnt+=1
                if n_curves and cnt >= n_curves:
                    break
                
            # Set axes limit
            if metric.startswith('f'):
                plt.xlim(0, 1)
                plt.ylim(0, 1)

            # plt.xlim(0, max(1, df_best.loc[:,:,ns,:][cols[0]].max()))
            # plt.ylim(0, max(1, df_best.loc[:,:,ns,:][cols[1]].max()))

            # Set titles
            ax.set_title(file)
            ax.set_xlabel(axis_title_dict[cols[0]], labelpad=20)
            ax.set_ylabel(axis_title_dict[cols[1]], labelpad=20)

            # Legend
            # ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
            leg = ax.legend(markerscale=6, title=file)
            for legobj in leg.get_lines():
                legobj.set_linewidth(10.0)
                
            leg.set_bbox_to_anchor((1.05, 1))  

            # Save figure on disk
            plt.savefig("{}/fig_{}_{}.png".format(out_folder, metric, ns), bbox_inches='tight', dpi=300, transparent=True)
            # plt.clf()



]]

# %% [markdown]
# ## Test Clara's function against Damiano's parser

# %%
ont_file = '/data/rashika/CAFA4/uniprot/go_2024_03_28/go-basic.obo' 
data = '/data/rashika/CAFA4/extracted_goa/t1_preprocessed.csv'

# %%
# Clara's

# %%
ont_graph = clean_ontology_edges(obonet.read_obo(ont_file))
subontologies = {aspect: fetch_aspect(ont_graph, roots[aspect]) for aspect in roots}

ann = pd.read_csv(data, sep="\t")
ann.columns = ['EntryID', 'term', 'aspect']
aspect_mapping = {
    'C': 'CCO',
    'F': 'MFO',
    'P': 'BPO'}
    
ann['aspect'] = ann['aspect'].map(aspect_mapping)
ann_prop = propagate_terms(ann, subontologies)

# %%
display(ann_prop)

# %%
# Damiano's

# %%
ia = None
no_orphans = False
# Parse the OBO file and creates a different graphs for each namespace
ontologies = obo_parser(ont_file, ("is_a", "part_of"), ia, not no_orphans)

# Parse ground truth file
#gt = gt_parser(data, ontologies)

# %%
x = gt['biological_process']

# %%
np.size(gt['biological_process'].matrix, 0)

# %%
np.size(gt['biological_process'].matrix, 1)

# %%
ontologies[ns].terms_dict

# %%
ontologies = obo_parser(ont_file, valid_rel=("is_a", "part_of"), ia_file=None, orphans=True)
ground_truth = gt_parser(data, ontologies)

# %%
def gt_as_df(gt, ontologies):
        dfs = []
        term_info = []
        for ns in ontologies:
            for index, p_id in enumerate(gt[ns].ids):
                GO_terms = list(ontologies[ns].terms_dict.keys())
                GO_terms = pd.DataFrame(GO_terms, columns = ['term'])
                GO_terms_In_p = gt[ns].matrix[index]==True
                GO_terms = GO_terms.loc[GO_terms_In_p]
                GO_terms['aspect'] = ns
                GO_terms['EntryID'] = p_id
                dfs.append(GO_terms)
        dfs = pd.concat(dfs)
        dfs = dfs.loc[:, ["EntryID", "term", "aspect"]].copy()
        return dfs

# Example usage:

#ground_truth = ground_truth['biological_process']


dfs = gt_as_df(ground_truth,ontologies)
    #for protein_id, term_id in term_info:
        #print("Protein ID: {}, Term ID: {}".format(protein_id, term_id))

# %%
dfs

# %%
aspect_mapping = {
    'cellular_component' :'CCO',
    'molecular_function': 'MFO',
    'biological_process': 'BPO'}
    
dfs['aspect'] = dfs['aspect'].map(aspect_mapping)
display(dfs)

# %%
# Find elements in df1 that are not in df2
df1_unique = pd.concat([dfs, ann_prop]).drop_duplicates(keep=False)
df1_unique = df1_unique.dropna()  # Drop rows with NaN values, if any

# Find elements in df2 that are not in df1
df2_unique = pd.concat([ann_prop, dfs]).drop_duplicates(keep=False)
df2_unique = df2_unique.dropna()  # Drop rows with NaN values, if any

# %%
df1_unique

# %%
df2_unique

# %%
gt_info = get_term_info(x)

# %%
gt_info 
i = 0
terms = []
for term_id, score, aspect in gt_info:
    print("Term ID: {}, Score: {}, Aspect: {}".format(term_id, score, aspect))
    i+=1
    terms.append(term_id)
i

# %%
len(np.unique(terms))

# %%
gt['biological_process']

# %%
ls ../../CAFA-evaluator/src/cafaeval/

# %% [markdown]
# Bootstrapping Development on sample

# %%
ont_file = '/data/rashika/CAFA4/uniprot/goa_2020_Jan_03/go-basic.obo' # data-version: releases/2020-01-01
#pred_dir = '/data/rashika/CAFA4/pred_sample/' # 20 methods
pred_dir ='/home/rashika/CAFA4/one/' # 1 method
BM_GO_file = '/data/rashika/CAFA4/eval/BM_GO/cco_all_type1.txt'
IA_file =  "/data/rashika/CAFA4/eval/IA/IA.txt"
out_dir = "/data/rashika/CAFA4/test_b"


cmd = "python3 /home/rashika/CAFA4/CAFA-evaluator/src/cafaeval/__main__.py "+ ont_file +" "+ pred_dir + " " + BM_GO_file + " -out_dir " + out_dir + ' -ia ' + IA_file + " -prop max -th_step 0.01  -no_orphans -b 10" + " &"
print(cmd)
#os.system(cmd)

# %%
/Users/rashi/Documents/Academics/Research/CAFA4_eval/Damiano_code/test_data/go-basic.obo /Users/rashi/Documents/Academics/Research/CAFA4_eval/Damiano_code/test_data/one/ /Users/rashi/Documents/Academics/Research/CAFA4_eval/Damiano_code/test_data/cco_all_type1.txt -out_dir /Users/rashi/Documents/Academics/Research/CAFA4_eval/Damiano_code/output -ia /Users/rashi/Documents/Academics/Research/CAFA4_eval/Damiano_code/test_data/IA.txt -prop max -th_step 0.01  -no_orphans -b 10

# %%
roots = {'BPO': 'GO:0008150', 'CCO': 'GO:0005575', 'MFO': 'GO:0003674'}

work_dir = "/data/rashika/CAFA4/"
t0_mapped_path = work_dir + "mapped/t0.csv"
t1_mapped_path = work_dir + "/mapped/t1.csv"

t0_ont_file = '/data/rashika/CAFA4/uniprot/goa_2020_Jan_03/go-basic.obo' # data-version: releases/2020-01-01
t0_ont_graph = clean_ontology_edges(obonet.read_obo(t0_ont_file)) 
    
t1_mapped_ann =  "/data/rashika/CAFA4/mapped/t1_mapped.csv"
t1_ont_graph = clean_ontology_edges(obonet.read_obo( "/data/rashika/CAFA4/uniprot/goa_2024-02-09/go-basic.obo")) # data-version: releases/2024-01-17
    
#Prop t0 and t1 in their respective ontologies
t0_prop = process_raw_annot(t0_mapped_path, t0_ont_graph, roots, remove_roots = False)
t1_prop = process_raw_annot(t1_mapped_path, t1_ont_graph, roots, remove_roots = False)
    
# Keep common terms
t0_common, t1_common =  keep_common_go_terms(t0_prop, t1_prop, t0_ont_graph, t1_ont_graph)
t0_common.to_csv('/data/rashika/CAFA4/common/t0.tsv', sep = '\t', header = False, index = False)
t1_common.to_csv('/data/rashika/CAFA4/common/t1.tsv', sep = '\t', header = False, index = False)

# %%
# Obtain the plots
# Results of 5 methods
data_path = result_path
plots_path = "/data/rashika/CAFA4/eval/" + "plots/"
plots_path_f_w = plots_path+'f_w/'
plots_path_f = plots_path+'f/'
plots_path_f_micro_w = plots_path+'f_micro_w/'
plots_path_s_w = plots_path+'s_w/'
register = '/data/rashika/CAFA4/file_map.tsv'

metric, cols = ('f_w', ['rc_w', 'pr_w'])
#create_plots(results_path, metric, cols,out_path='/home/rashika/CAFA4/eval/plots/', n_curves = None, names_file = None):
create_plots(data_path, metric, cols, out_path = plots_path_f_w, n_curves = 10, names_file = register)

metric, cols = ('f', ['rc', 'pr'])
create_plots(data_path, metric, cols, out_path = plots_path_f, n_curves = 10, names_file = register)

metric, cols =  ('f_micro_w', ['rc_micro_w', 'pr_micro_w'])
create_plots(data_path, metric, cols, out_path = plots_path_f_micro_w, n_curves = 10, names_file = register)

metric, cols = ('s_w', ['ru_w', 'mi_w'])
create_plots(data_path, metric, cols, out_path = plots_path_s_w, n_curves = 10, names_file = register)

# %%
# Bootstrapping

# %%
roots = {'BPO': 'GO:0008150', 'CCO': 'GO:0005575', 'MFO': 'GO:0003674'}

t0_ont_file = '/data/rashika/CAFA4/uniprot/goa_2020_Jan_03/go-basic.obo' # data-version: releases/2020-01-01
t0_ont_graph = clean_ontology_edges(obonet.read_obo(t0_ont_file)) 
shawn_t0_mapped_ann = "/data/rashika/CAFA4/CAFA4_gt/t0_mapped.csv"

t1_mapped_ann = "/data/rashika/CAFA4/CAFA4_gt/t1_mapped.csv"
t1_ont_graph = clean_ontology_edges(obonet.read_obo( "/data/rashika/CAFA4/uniprot/goa_2024-02-09/go-basic.obo")) # data-version: releases/2024-01-17

BM_path = "/home/rashika/CAFA4/eval/benchmarks/"
BM_GO_path = "/home/rashika/CAFA4/eval/benchmarks_GO/"

# Create BM lists
#t1_eval = create_bm_lists(shawn_t0_mapped_ann, t1_mapped_ann, t0_ont_graph, t1_ont_graph, roots, BM_path)

# %%
import os

# %%
def generate_image_code(directory):
        image_code = ''
        for root, dirs, files in os.walk(directory):
            for sub_dir in dirs:
                print(sub_dir)
                print(directory +sub_dir)
                for _, _, files_sub_dir in os.walk(directory +sub_dir):
                    for file in files_sub_dir:
                        print(str(file))
                        if file.endswith(".png"):
                            image_path = os.path.join(root, file)
                            folder = os.path.basename(root)
                            image_code += "\\begin{subfigure}[b]{0.3\\textwidth}\n"
                            image_code += "\\centering\n"
                            image_code += "\\includegraphics[width=\\textwidth]{" + image_path + "}\n"
                            image_code += "\\caption{Figure in \\texttt{" + folder + "}}\n"
                            image_code += "\\label{fig:" + folder + ":" + file + "}\n"
                            image_code += "\\end{subfigure}\n"
            return image_code

# %%
# Call function to generate image code for current directory
latex_image_code = generate_image_code('/home/rashika/CAFA4/eval/plots_ALL/f/')

# %%
latex_image_code
